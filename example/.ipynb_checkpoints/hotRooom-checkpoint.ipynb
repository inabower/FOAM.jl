# %%
include("src/FOAM.jl")
using PyPlot

# %%
orgCase = ENV["FOAM_TUTORIALS"] * "/heatTransfer/buoyantPimpleFoam/hotRoom"
case = "hotRoom_buoyantPimpleFoam"
if !isdir("test")
    mkdir("test")
end
n = 0
while true
    name = joinpath("./test",join([case,n],"_"))
    if !isdir(name)
        case = name
        break
    end
    n += 1
end
run(`cp -r $orgCase $case`)

# %%
runCase(case)

# %%
regions = readRegion(case)
times = timeList(case)
meshProp = checkMesh(case)
println("regions : ",keys(regions))
println("latest time : ",times[end])
for region in keys(regions)
    println("  nPoints = ",meshProp[region]["nPoints"])
    println("  nFaces = ",meshProp[region]["nFaces"])
    println("  nCells = ",meshProp[region]["nCells"])
    fields = fieldList(case, "latestTime", string(region))
    print("[Fields] : ")
    for f in fields
        print(f," ")
    end
end
# Out:
# regions : ["master"]
# latest time : 2000
#   nPoints = 4851
#   nFaces = 12800
#   nCells = 4000
# [Fields] : T U alphat epsilon k nut p p_rgh phi

# %%
t = "latestTime"
V = meshProp["master"]["cellVolumes"]
for fieldName in ["T","p","p_rgh","U","k","epsilon"]
    T = field(case, fieldName, t, "master")["internalField"]
    print(fieldName," Max/Mean/Min = ",maximum(T),"/",sum(T .* V) ./ sum(V),"/",minimum(T))
    println()
end
# Out:
# T Max/Mean/Min = 300.969/300.55087675/300.464
# p Max/Mean/Min = 100209/100183.6/100158
# p_rgh Max/Mean/Min = 100212/100212.0/100212
# U Max/Mean/Min = 0.156158/0.0004175429695605003/-0.0648351
# k Max/Mean/Min = 0.000466324/5.1538829947499994e-5/2.61062e-6
# epsilon Max/Mean/Min = 1.30279e-5/7.04500464875e-7/6.7715e-9

# %%
times = timeList(case)
fig = figure("result",figsize=(15,7));n = 1;pos = 230
V = meshProp["master"]["cellVolumes"]
nCells = meshProp["master"]["nCells"]
for fieldName in ["T","p","p_rgh","U","k","epsilon"]
    t = Float64[];ymean = Float64[];ymax = Float64[];ymin = Float64[]
    for time in keys(times)
        if time == 0.0 continue end
        if time % 10 != 0 continue end
        push!(t,time)
        T = field(case, fieldName, times[time], "master")["internalField"]
        if ndims(T) > 1 || length(T) == nCells;T = mag(T)
        else;T = fill(norm(T),nCells)
        end
        push!(ymean,sum(T .* V) ./ sum(V))
        push!(ymax,maximum(T))
        push!(ymin,minimum(T))
    end
    subplot(pos+n);title(fieldName)
    plot(t,ymean,label="mean");plot(t,ymax,label="max");plot(t,ymin,label="min")
    legend()
    n += 1
end
# Out:
# Figure(PyObject <Figure size 1500x700 with 6 Axes>)

# %%
for region in keys(regions)
    println("For region ", region)
    println("  nPoints = ",mesh[region]["nPoints"])
    println("  nFaces = ",mesh[region]["nFaces"])
    println("  nCells = ",mesh[region]["nCells"])
    println(" Face Area")
    println("  Min = ",minimum(mesh[region]["faceAreaValues"]))
    println("  Max = ",maximum(mesh[region]["faceAreaValues"]))
    println(" Volume")
    println("  Min = ",minimum(mesh[region]["cellVolumes"]))
    println("  Max = ",maximum(mesh[region]["cellVolumes"]))
    fields = fieldList(case, "latestTime", string(region))
    print("[Fields] : ")
    for f in fields
        print(f," ")
    end
    println()
    println()
end
